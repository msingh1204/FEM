# %%
from scipy.special import roots_jacobi, eval_jacobi
import pandas as pd
import numpy as np
import uxarray as ux
import xarray as xr

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %% [markdown]
# ## ne5; DG:

# %%
A_conserv_cnflx = np.load("/home/hsingh/Downloads/DG_2D_conserv_centerflx_matrix_ne5.npy")
A_conserv_cnflx_eigs = np.linalg.eigvals(-A_conserv_cnflx)

# %%
plt.scatter(A_conserv_cnflx_eigs.real, A_conserv_cnflx_eigs.imag)

# %%
A_conserv_upflx = np.load("/home/hsingh/Downloads/DG_2D_conserv_upwindflx_matrix_ne5.npy")
A_conserv_upflx_eigs = np.linalg.eigvals(-A_conserv_upflx)

# %%
plt.scatter(A_conserv_upflx_eigs.real, A_conserv_upflx_eigs.imag)

# %%
A_splfrm_cnflx = np.load("/home/hsingh/Downloads/DG_2D_splfrm_centerflx_matrix_ne5.npy")
A_splfrm_cnflx_eigs = np.linalg.eigvals(-A_splfrm_cnflx)

# %%
plt.scatter(A_splfrm_cnflx_eigs.real, A_splfrm_cnflx_eigs.imag)

# %%
A_splfrm_upflx = np.load("/home/hsingh/Downloads/DG_2D_splfrm_upwindflx_matrix.npy")
A_splfrm_upflx_eigs = np.linalg.eigvals(-A_splfrm_upflx)

# %%
plt.scatter(A_splfrm_upflx_eigs.real, A_splfrm_upflx_eigs.imag)
